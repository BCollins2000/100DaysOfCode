# %%
print("Welcome to the rollercoaster!!!")
height = int(input("What is your height in centimeters? "))

if height >= 120:
    print("Welcome abord! You are tall enough to ride 😄")
else:
    print("Sorry you are not tall enough to ride ☹️")

# %%
# Odd or Even Check
number = int(input("Enter a number "))

Remainder = number % 2
if Remainder == 1:
    print(str(number) + " is odd")
else:
    print(str(number) + " is even")

# %%
# Nested if statements:

height = int(input("Please enter your height in centimeters "))

if height >= 120:
    age = int(input("Please enter your age in years "))
    if age <=5:
        print("You are very tall, but too young for this ride")
    elif age <= 12:
        print("Welcome kiddo, please pay $3")
    elif age <= 18:
        print("Totally tubular, please pay $8")
    else:
        print("Life ain't fair, that will be $35")
else:
    print("Sorry you are not tall enough to ride ☹️")

# %%
#BMI Calculator 2.0:
height = float(input("Please enter your height in meters"))
weight = float(input("Please enter your weight in kilograms"))

BMI = round(weight/(height**2),1)

if BMI < 18.5:
    print(f"Your BMI is {BMI} and you are underweight.")
elif BMI < 25:
    print(f"Your BMI is {BMI} and you are a normal weight.")
elif BMI < 30:
    print(f"Your BMI is {BMI} and you are slightly overweight.")
elif BMI < 35:
    print(f"Your BMI is {BMI} and you are obese.")
else:
    print(f"Your BMI is {BMI} and you are clinically obese.")

# %%
# Which year do you want to check?
year = int(input("Choose a year"))

year_div_4_remainder = year % 4 
year_div_100_remainder = year % 100
year_div_400_remainder = year % 400

if year_div_4_remainder != 0:
  print(f"{year} is not a leap year")
elif year_div_100_remainder != 0:
  print(f"{year} is a leap year")
elif year_div_400_remainder == 0:
  print(f"{year} is a leap year")  
else:
  print(f"{year} is not a leap year")

# %%
# Nested if statements:

height = int(input("Please enter your height in centimeters "))

if height >= 120:
    age = int(input("Please enter your age in years "))
    if age <=12:
        bill = 5
        print("Child Tickets are $5")
    elif age <= 18:
        bill = 7
        print("Youth Tickets are $7")
    elif age <= 55 and age >= 45:
        bill = 0
        print("Free Ride due to Midlife Crisis")    
    else:
        bill = 12
        print("Adult Tickets are $12")
    wants_photo = input("Do you want a photo taken for $3? Y or N")
    if wants_photo == "Y":
        bill += 3
    print(f"Your final bill is ${bill}")
else:
    print("Sorry you are not tall enough to ride ☹️")

# %%
print("Thank you for choosing Python Pizza Deliveries!")
size = input("What size pizza do you want? S, M, or L ") 
add_pepperoni = input("Do you want pepperoni? Y or N ") 
extra_cheese = input("Do you want extra cheese? Y or N ") 

if size == "S":
  bill = 15
  if add_pepperoni == "Y":
    bill += 2
elif size == "M":
  bill = 20
  if add_pepperoni == "Y":
    bill += 3
elif size == "L":
  bill = 25
  if add_pepperoni == "Y":
    bill += 3

if extra_cheese == "Y":
  bill += 1

print(f"Your final bill is: ${bill}.")

# %%
print("The Love Calculator is calculating your score...")
name1 = "Brad Pitt"
name2 = "Angelina Jolie"
# 🚨 Don't change the code above 👆
# Write your code below this line 👇

true_count_name1 = name1.lower().count('t') + name1.lower().count('r') + name1.lower().count('u') + name1.lower().count('e')
true_count_name2 = name2.lower().count('t') + name2.lower().count('r') + name2.lower().count('u') + name2.lower().count('e')
true_count = true_count_name1 + true_count_name2

love_count_name1 = name1.lower().count('l') + name1.lower().count('o') + name1.lower().count('v') + name1.lower().count('e')
love_count_name2 = name2.lower().count('l') + name2.lower().count('o') + name2.lower().count('v') + name2.lower().count('e')
love_count = love_count_name1 + love_count_name2

love_score = 10*true_count + love_count
if love_score < 10 or love_score > 90: 
    print(f"Your score is {love_score}, you go together like coke and mentos.")
elif love_score >= 40 and love_score <= 50: 
    print(f"Your score is {love_score}, you are alright together.")
else: 
    print(f"Your score is {love_score}.")

# %%
### This block of code will walk the user through a mini-game called treasure island.
print('Welcome to teaseure island!')
direction = input("Left or Right? ").lower()
if direction == 'left':
    swim_choose = input("You walk left and find yourself at a beach. Do you choose to Swim or Wait? ").lower()
    if swim_choose == 'wait':
        which_door = input("You choose to wait and suddenly three doors appear. Do you choose the Red, Blue or Yellow?").lower()
        if which_door == "red":
            print('You open the Red door and get engulfed in flames. Game over.')
        elif which_door == "blue":
            print('You open the Blue door and get frozen by the Night King. Game Over.')
        elif which_door == "yellow":
            print('You open the Yellow door and find a friendly leprechaun and a massive pot of gold. You win!!') 
        else:
            print('You did not choose a proper door color. Game over') 
            
    else: print('You swim too far off the coast and down. Game over.')
else: print("Sorry you fell into a deep pit. Game over.")
